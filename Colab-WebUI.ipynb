# %% [markdown]
# <a href="https://colab.research.google.com/github/Deep-Octopus/Deep-Octopus/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Overwriting /content/setup.sh

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ✨🍰✨ Everything looks OK!
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# bash: /usr/local/lib/libtinfo.so.6: no version information available (required by bash)
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://bd35a288a81682bac5.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/1-get-text.py
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/1-get-text.py
# Tokenization & BERT Feature Extraction Process Terminated
# Tokenization & BERT Feature Extraction Process Terminated
# Traceback (most recent call last):
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/queueing.py", line 575, in process_events
#     response = await route_utils.call_process_api(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/blocks.py", line 1935, in process_api
#     result = await self.call_function(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/blocks.py", line 1532, in call_function
#     prediction = await utils.async_iteration(iterator)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 671, in async_iteration
#     return await iterator.__anext__()
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 664, in __anext__
#     return await anyio.to_thread.run_sync(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/anyio/to_thread.py", line 56, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2470, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 967, in run
#     result = context.run(func, *args)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 647, in run_sync_iterator_async
#     return next(iterator)
#   File "/usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/gradio/utils.py", line 809, in gen_wrapper
#     response = next(iterator)
#   File "/content/GPT-SoVITS/webui.py", line 826, in open1a
#     with open(txt_path, "r", encoding="utf8") as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'logs/sun/2-name2text-0.txt'
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/s2_train.py --config "/content/GPT-SoVITS/TEMP/tmp_s2.json"
# INFO:zj:{'train': {'log_interval': 100, 'eval_interval': 500, 'seed': 1234, 'epochs': 25, 'learning_rate': 0.0001, 'betas': [0.8, 0.99], 'eps': 1e-09, 'batch_size': 6, 'fp16_run': True, 'lr_decay': 0.999875, 'segment_size': 20480, 'init_lr_ratio': 1, 'warmup_epochs': 0, 'c_mel': 45, 'c_kl': 1.0, 'text_low_lr_rate': 0.4, 'grad_ckpt': False, 'pretrained_s2G': 'GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth', 'pretrained_s2D': 'GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth', 'if_save_latest': True, 'if_save_every_weights': True, 'save_every_epoch': 4, 'gpu_numbers': '0', 'lora_rank': '32'}, 'data': {'max_wav_value': 32768.0, 'sampling_rate': 32000, 'filter_length': 2048, 'hop_length': 640, 'win_length': 2048, 'n_mel_channels': 128, 'mel_fmin': 0.0, 'mel_fmax': None, 'add_blank': True, 'n_speakers': 300, 'cleaned_text': True, 'exp_dir': 'logs/zj'}, 'model': {'inter_channels': 192, 'hidden_channels': 192, 'filter_channels': 768, 'n_heads': 2, 'n_layers': 6, 'kernel_size': 3, 'p_dropout': 0.0, 'resblock': '1', 'resblock_kernel_sizes': [3, 7, 11], 'resblock_dilation_sizes': [[1, 3, 5], [1, 3, 5], [1, 3, 5]], 'upsample_rates': [10, 8, 2, 2, 2], 'upsample_initial_channel': 512, 'upsample_kernel_sizes': [16, 16, 8, 2, 2], 'n_layers_q': 3, 'use_spectral_norm': False, 'gin_channels': 1024, 'semantic_frame_rate': '25hz', 'freeze_quantizer': True, 'version': 'v2Pro'}, 's2_ckpt_dir': 'logs/zj', 'content_module': 'cnhubert', 'save_weight_dir': 'SoVITS_weights_v2Pro', 'name': 'zj', 'version': 'v2Pro', 'pretrain': None, 'resume_step': None}
# phoneme_data_len: 12
# wav_data_len: 96
# 100% 96/96 [00:00<00:00, 81990.06it/s]
# skipped_phone:  0 , skipped_dur:  0
# total left:  96
# logs/zj/logs_s2_v2Pro/D_233333333333.pth
# load
# INFO:zj:Loaded checkpoint 'logs/zj/logs_s2_v2Pro/D_233333333333.pth' (iteration 24)
# INFO:zj:loaded D
# logs/zj/logs_s2_v2Pro/G_233333333333.pth
# load
# INFO:zj:Loaded checkpoint 'logs/zj/logs_s2_v2Pro/G_233333333333.pth' (iteration 24)
# start training from epoch 25
#   0% 0/17 [00:00<?, ?it/s][rank0]:[W616 12:51:49.755378289 reducer.cpp:1400] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# 100% 17/17 [00:49<00:00,  2.90s/it]
# INFO:zj:====> Epoch: 25
# training done
# [rank0]:[W616 12:52:07.735553924 ProcessGroupNCCL.cpp:1496] Warning: WARNING: destroy_process_group() was not called before program exit, which can leak resources. For more info, please see https://pytorch.org/docs/stable/distributed.html#shutdown (function operator())
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/s1_train.py --config_file "/content/GPT-SoVITS/TEMP/tmp_s1.yaml"
# Seed set to 1234
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# <All keys matched successfully>
# ckpt_path: logs/zj/logs_s1_v2Pro/ckpt/epoch=9-step=30.ckpt
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# semantic_data_len: 12
# phoneme_data_len: 12
#                                             item_name                                     semantic_audio
# 0   vocal_vocal_clone-video.mp3_10.wav_10.wav_0000...  759 15 988 984 85 7 997 7 736 52 1003 600 600 ...
# 1   vocal_vocal_clone-video.mp3_10.wav_10.wav_0000...  54 509 594 515 41 271 271 72 277 932 794 915 5...
# 2   vocal_vocal_clone-video.mp3_10.wav_10.wav_0000...  520 72 214 220 733 572 936 318 234 722 53 105 ...
# 3   vocal_vocal_clone-video.mp3_10.wav_10.wav_0001...  520 105 105 536 520 105 72 885 600 292 740 730...
# 4   vocal_vocal_clone-video.mp3_10.wav_10.wav_0001...  520 271 271 72 714 265 765 77 31 663 334 208 1...
# 5   vocal_vocal_clone-video.mp3_10.wav_10.wav_0001...  520 271 271 271 72 29 81 794 95 400 948 333 67...
# 6   vocal_vocal_clone-video.mp3_10.wav_10.wav_0000...  520 105 105 105 280 280 280 105 105 72 492 950...
# 7   vocal_vocal_clone-video.mp3_10.wav_10.wav_0000...  520 271 105 105 105 105 105 271 505 69 794 144...
# 8   vocal_vocal_clone-video.mp3_10.wav_10.wav_0000...  54 505 208 81 77 980 604 804 242 368 40 616 75...
# 9   vocal_vocal_clone-video.mp3_10.wav_10.wav_0001...  520 505 1005 915 39 77 508 797 14 913 592 575 ...
# 10  vocal_vocal_clone-video.mp3_10.wav_10.wav_0001...  520 105 105 105 105 105 105 105 105 271 98 70 ...
# 11  vocal_vocal_clone-video.mp3_10.wav_10.wav_0002...  520 72 72 405 902 288 275 939 420 573 747 1005...
# dataset.__len__(): 96
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:654: Checkpoint directory /content/GPT-SoVITS/logs/zj/logs_s1_v2Pro/ckpt exists and is not empty.
# Restoring states from the checkpoint path at logs/zj/logs_s1_v2Pro/ckpt/epoch=9-step=30.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type                 | Params | Mode
# -------------------------------------------------------
# 0 | model | Text2SemanticDecoder | 77.6 M | train
# -------------------------------------------------------
# 77.6 M    Trainable params
# 0         Non-trainable params
# 77.6 M    Total params
# 310.426   Total estimated model params size (MB)
# 257       Modules in train mode
# 0         Modules in eval mode
# Restored all states from the checkpoint at logs/zj/logs_s1_v2Pro/ckpt/epoch=9-step=30.ckpt
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/pytorch_lightning/loops/fit_loop.py:310: The number of training batches (24) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# `Trainer.fit` stopped: `max_epochs=10` reached.
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/inference_webui.py "Auto"
# SoVITS_weights_v2Pro/zj_e24_s408.pth v2 v2Pro False
# loading sovits_v2Pro <All keys matched successfully>
# Running on local URL:  http://0.0.0.0:9872
# Running on public URL: https://9aacdf97ac7498a7cd.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Actual Input Reference Text: 后边在西京这边要做的其实是有点类似的，所以你们呢可能后边在小蒋的组织下呢会进行一些这种。
# Actual Input Target Text: 大家好，这是我的公众号:AI技术实战，我经常分享一些关于AI的技术、数学、编程、开源项目，希望与大家一起交流
# Actual Input Target Text (after sentence segmentation): 大家好，这是我的公众号:AI技术实战，我经常分享一些关于AI的技术、数学、编程、开源项目，希望与大家一起交流。
# Actual Input Target Text (per sentence): 大家好，这是我的公众号:AI技术实战，我经常分享一些关于AI的技术、数学、编程、开源项目，希望与大家一起交流。
# INFO:fast_langdetect.infer:fast-langdetect: Downloading model from https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin
# [2025-06-16 13:02:40,409][INFO] - Downloading https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin to lid.176.bin (125.2M)
# INFO:robust_downloader.downloader:Downloading https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin to lid.176.bin (125.2M)
# 100% 125M/125M [00:01<00:00, 80.4MB/s]
# ['大家好,这是我的公众号', 'AI', '技术实战,我经常分享一些关于', 'AI', '的技术,数学,编程,开源项目,希望与大家一起交流.']
# ['zh', 'en', 'zh', 'en', 'zh']
# Processed text from the frontend (per sentence): 大家好,这是我的公众号A I技术实战,我经常分享一些关于A I的技术,数学,编程,开源项目,希望与大家一起交流.
#  17% 252/1500 [00:02<00:10, 116.93it/s]T2S Decoding EOS [205 -> 460]
#  17% 254/1500 [00:02<00:12, 102.28it/s]
# 2.443	14.806	2.491	1.280
# Actual Input Reference Text: 后边在西京这边要做的其实是有点类似的，所以你们呢可能后边在小蒋的组织下呢会进行一些这种。
# Actual Input Target Text: 今天影像方向跟小梁，和赵瑞、李雪布置了这个他们的工作。我明天要上午尽快把硬盘一买，然后跟这个刘畅、张帅、小季他们开会的时候，首先花了一个小时的时间。把这个数据电脑怎么整，大概规划了一下。首先呢，把5号的这个电脑，把它清理成专门用来处理糖度的这个数据。然后这个，然后徐义峰的工作。让他跟这个小何再去讨论几天，周四然后让他讲。这个张帅呢，让他去整理欧萨的 RAM 和 non RAM 欧萨直接比较差异的那些文献，然后再把欧萨所有的 review 都整一下，然后过两天让这个小叶，还有张帅，还有这个潜在的线上的科研助理小迪去把这个综述的文章讨论一下，然后刘畅这边呢，是把文章继续往下写，然后把功率谱和非脑耦合的失眠和这个这个这个欧萨的文章再整理一下，然后方法的部分跟学生们去对接，然后也是周四过一下
# Actual Input Target Text (after sentence segmentation): 今天影像方向跟小梁，和赵瑞、李雪布置了这个他们的工作。我明天要上午尽快把硬盘一买，然后跟这个刘畅、张帅、小季他们开会的时候，
# 首先花了一个小时的时间。把这个数据电脑怎么整，大概规划了一下。首先呢，把5号的这个电脑，把它清理成专门用来处理糖度的这个数据。
# 然后这个，然后徐义峰的工作。让他跟这个小何再去讨论几天，周四然后让他讲。这个张帅呢，让他去整理欧萨的 RAM 和 non RAM 欧萨直接比较差异的那些文献，
# 然后再把欧萨所有的 review 都整一下，然后过两天让这个小叶，还有张帅，还有这个潜在的线上的科研助理小迪去把这个综述的文章讨论一下，
# 然后刘畅这边呢，是把文章继续往下写，然后把功率谱和非脑耦合的失眠和这个这个这个欧萨的文章再整理一下，然后方法的部分跟学生们去对接，然后也是周四过一下。
# Actual Input Target Text (per sentence): 今天影像方向跟小梁，和赵瑞、李雪布置了这个他们的工作。我明天要上午尽快把硬盘一买，然后跟这个刘畅、张帅、小季他们开会的时候，
# Processed text from the frontend (per sentence): 今天影像方向跟小梁,和赵瑞,李雪布置了这个他们的工作.我明天要上午尽快把硬盘一买,然后跟这个刘畅,张帅,小季他们开会的时候,
#  17% 260/1500 [00:02<00:10, 115.25it/s]T2S Decoding EOS [205 -> 469]
#  18% 263/1500 [00:02<00:10, 115.90it/s]
# Actual Input Target Text (per sentence): 首先花了一个小时的时间。把这个数据电脑怎么整，大概规划了一下。首先呢，把5号的这个电脑，把它清理成专门用来处理糖度的这个数据。
# Processed text from the frontend (per sentence): 首先花了一个小时的时间.把这个数据电脑怎么整,大概规划了一下.首先呢,把五号的这个电脑,把它清理成专门用来处理糖度的这个数据.
#  16% 235/1500 [00:02<00:15, 83.61it/s]T2S Decoding EOS [205 -> 446]
#  16% 240/1500 [00:02<00:12, 102.77it/s]
# Actual Input Target Text (per sentence): 然后这个，然后徐义峰的工作。让他跟这个小何再去讨论几天，周四然后让他讲。这个张帅呢，让他去整理欧萨的 RAM 和 non RAM 欧萨直接比较差异的那些文献，
# ['然后这个,然后徐义峰的工作.让他跟这个小何再去讨论几天,周四然后让他讲.这个张帅呢,让他去整理欧萨的', 'RAM', '和', 'NONRAM', '欧萨直接比较差异的那些文献,']
# ['zh', 'en', 'zh', 'en', 'zh']
# Processed text from the frontend (per sentence): 然后这个,然后徐义峰的工作.让他跟这个小何再去讨论几天,周四然后让他讲.这个张帅呢,让他去整理欧萨的R A M和N O N R A M欧萨直接比较差异的那些文献,
#  20% 300/1500 [00:02<00:10, 115.92it/s]T2S Decoding EOS [205 -> 514]
#  21% 308/1500 [00:02<00:11, 107.98it/s]
# Actual Input Target Text (per sentence): 然后再把欧萨所有的 review 都整一下，然后过两天让这个小叶，还有张帅，还有这个潜在的线上的科研助理小迪去把这个综述的文章讨论一下，
# ['然后再把欧萨所有的', 'REVIEW', '都整一下,然后过两天让这个小叶,还有张帅,还有这个潜在的线上的科研助理小迪去把这个综述的文章讨论一下,']
# ['zh', 'en', 'zh']
# Processed text from the frontend (per sentence): 然后再把欧萨所有的R E V I E W都整一下,然后过两天让这个小叶,还有张帅,还有这个潜在的线上的科研助理小迪去把这个综述的文章讨论一下,
#  19% 290/1500 [00:02<00:10, 115.13it/s]T2S Decoding EOS [205 -> 504]
#  20% 298/1500 [00:02<00:10, 113.65it/s]
# Actual Input Target Text (per sentence): 然后刘畅这边呢，是把文章继续往下写，然后把功率谱和非脑耦合的失眠和这个这个这个欧萨的文章再整理一下，然后方法的部分跟学生们去对接，然后也是周四过一下。
# Processed text from the frontend (per sentence): 然后刘畅这边呢,是把文章继续往下写,然后把功率谱和非脑耦合的失眠和这个这个这个欧萨的文章再整理一下,然后方法的部分跟学生们去对接,然后也是周四过一下.
#  23% 345/1500 [00:02<00:10, 113.61it/s]T2S Decoding EOS [205 -> 557]
#  23% 351/1500 [00:03<00:09, 115.61it/s]
# 0.066	0.685	13.130	2.020
# Actual Input Reference Text: 后边在西京这边要做的其实是有点类似的，所以你们呢可能后边在小蒋的组织下呢会进行一些这种。
# Actual Input Target Text: 小张同学要永远爱小马同学，小马同学也要永远爱小张同学，你们要永远在一起哦
# Actual Input Target Text (after sentence segmentation): 小张同学要永远爱小马同学，小马同学也要永远爱小张同学，你们要永远在一起哦。
# Actual Input Target Text (per sentence): 小张同学要永远爱小马同学，小马同学也要永远爱小张同学，你们要永远在一起哦。
# Processed text from the frontend (per sentence): 小张同学要永远爱小马同学,小马同学也要永远爱小张同学,你们要永远在一起哦.
#  11% 162/1500 [00:01<00:11, 118.21it/s]T2S Decoding EOS [205 -> 376]
#  11% 170/1500 [00:01<00:11, 115.78it/s]
# 0.066	0.166	1.471	0.297
